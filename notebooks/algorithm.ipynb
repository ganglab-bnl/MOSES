# %% [markdown]
# # MOSES: DNA Origami Coloring Algorithm
#
# **Contributors:** Dr. Jason Kahn (Brookhaven), Sarah Hong (Columbia)
#
# This notebook shows the final workflow for how to create a lattice structure and paint it.

# %%
# Load this cell so that changes made in other files will be automatically reflected
# %load_ext autoreload
# %autoreload 2

# %%
# Run this cell to load all imports
import sys
sys.path.append('../')

import numpy as np
from PyQt6.QtWidgets import QApplication
from PyQt6.QtCore import QCoreApplication

from app.design.Designer import RunDesigner
from app.visualize.Visualizer import RunVisualizer
from algorithm.lattice.Lattice2 import Lattice
from algorithm.painting.Painter2 import Painter
from algorithm.painting.BindingFlexibility import BindingFlexibility

# %% [markdown]
# ## Create the lattice
# Run the below cell to open a GUI which allows you to quickly create arbitrary lattice structures.
#
# These lattices are encoded as numpy arrays and are saved to a (renamable) file called `lattice.npy` in the `notebooks/data` subdirectory. You can also use this feature to save and reload arbitrary lattice designs you've previously created.

# %%
# %gui qt

if __name__ == '__main__':
    if not QCoreApplication.instance():
        app = QApplication(sys.argv)
    else:
        app = QCoreApplication.instance()
    
    designer = RunDesigner(app)
    input_lattice = designer.run()
    
    if input_lattice is not None:
        print('Lattice received.')
        # rename this to whatever you want to call your lattice
        np.save("data/lattice.npy", input_lattice) 
    else:
        print("No lattice received.")

# %% [markdown]
# ## Running the algorithm
#
# ### Load lattice from file
# We can load in the lattice we created with `np.load(filename.npy)`. Since the lattice is just a numpy array, you can also create your own arbitrary lattices without the designer by creating arbitrary numpy arrays yourself.
#
# Some examples to run:
# - `double_oreo.npy`
# - `perovskite.npy`
# - `mini_helix.npy`
# - `helix.npy`
#
# ### Painting algorithm
# All you need to do to run the algorithm is to create a Lattice instance, `compute_symmetries()`, create a Painter instance, and `paint_lattice()`.
#
# The example workflow is detailed below.

# %%
# An example lattice structure you can load in
input_lattice = np.load('data/helix.npy')

# Initialize the data structures and compute all symmetries
lattice = Lattice(input_lattice)
lattice.compute_symmetries()

# Paint the lattice
painter = Painter(lattice, verbose=True) # Set verbose=True to print debug
painter.paint_lattice()
# Out:
# ===== STARTING STR_PAINT_LATTICE =====
# 	 ---> painting 1 onto voxel 0's bond +x with type structural
# 	 ---> painting -1 onto voxel 1's bond -x with type structural
#
# --- PAINT S_BOND (1) ---
# voxel_0 ((1, 0, 0)) <---> voxel_1 ((-1, 0, 0))
# self-sym paint(voxel_0)
#     map_paint(parent_0 --> child_0, sym=translation, with_negation=False)
#         parent = ['+x (1),', '-x (None),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (1),', '-x (None),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -x is none
# oops! parent bond +y is none
# oops! parent bond -y is none
# oops! parent bond +z is none
# oops! parent bond -z is none
#     map_paint(parent_0 --> child_0, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#         parent = ['+x (1),', '-x (None),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (1),', '-x (None),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# 	 ---> painting 1 onto voxel 0's bond -y with type structural
# 	 ---> painting -1 onto voxel 3's bond +y with type structural
# oops! parent bond +y is none
# oops! parent bond -x is none
# oops! parent bond +x is none
# oops! parent bond -z is none
# oops! parent bond +z is none
#     map_paint(parent_0 --> child_0, sym=270° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (1),', '-x (None),', '+y (None),', '-y (1),', '+z (None),', '-z (None),']
#         child = ['+x (1),', '-x (None),', '+y (None),', '-y (1),', '+z (None),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +y is none
# oops! parent bond -x is none
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -z is none
# oops! parent bond +z is none
# self-sym paint(voxel_1)
#     map_paint(parent_1 --> child_1, sym=translation, with_negation=False)
#         parent = ['+x (None),', '-x (-1),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (-1),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# oops! parent bond +x is none
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond +y is none
# oops! parent bond -y is none
# oops! parent bond +z is none
# oops! parent bond -z is none
# 	 ---> painting 2 onto voxel 0's bond -x with type structural
# 	 ---> painting -2 onto voxel 2's bond +x with type structural
#
# --- PAINT S_BOND (2) ---
# voxel_0 ((-1, 0, 0)) <---> voxel_2 ((1, 0, 0))
# self-sym paint(voxel_0)
#     map_paint(parent_0 --> child_0, sym=translation, with_negation=False)
#         parent = ['+x (1),', '-x (2),', '+y (None),', '-y (1),', '+z (None),', '-z (None),']
#         child = ['+x (1),', '-x (2),', '+y (None),', '-y (1),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond +y is none
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! parent bond -z is none
#     map_paint(parent_0 --> child_0, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#         parent = ['+x (1),', '-x (2),', '+y (None),', '-y (1),', '+z (None),', '-z (None),']
#         child = ['+x (1),', '-x (2),', '+y (None),', '-y (1),', '+z (None),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# 	 ---> painting 2 onto voxel 0's bond +y with type structural
# 	 ---> painting -2 onto voxel 6's bond -y with type structural
# oops! parent bond -x is none
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -z is none
# oops! parent bond +z is none
#     map_paint(parent_0 --> child_0, sym=270° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (None),', '-z (None),']
#         child = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (None),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -z is none
# oops! parent bond +z is none
# self-sym paint(voxel_2)
#     map_paint(parent_2 --> child_2, sym=translation, with_negation=False)
#         parent = ['+x (-2),', '-x (None),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (-2),', '-x (None),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -x is none
# oops! parent bond +y is none
# oops! parent bond -y is none
# oops! parent bond +z is none
# oops! parent bond -z is none
# 	 ---> painting 3 onto voxel 1's bond +x with type structural
# 	 ---> painting -3 onto voxel 2's bond -x with type structural
#
# --- PAINT S_BOND (3) ---
# voxel_1 ((1, 0, 0)) <---> voxel_2 ((-1, 0, 0))
# self-sym paint(voxel_1)
#     map_paint(parent_1 --> child_1, sym=translation, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (3),', '-x (-1),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond +y is none
# oops! parent bond -y is none
# oops! parent bond +z is none
# oops! parent bond -z is none
# self-sym paint(voxel_2)
#     map_paint(parent_2 --> child_2, sym=translation, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (-2),', '-x (-3),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond +y is none
# oops! parent bond -y is none
# oops! parent bond +z is none
# oops! parent bond -z is none
# 	 ---> painting 4 onto voxel 1's bond -y with type structural
# 	 ---> painting -4 onto voxel 4's bond +y with type structural
#
# --- PAINT S_BOND (4) ---
# voxel_1 ((0, -1, 0)) <---> voxel_4 ((0, 1, 0))
# self-sym paint(voxel_1)
#     map_paint(parent_1 --> child_1, sym=translation, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (None),', '-y (4),', '+z (None),', '-z (None),']
#         child = ['+x (3),', '-x (-1),', '+y (None),', '-y (4),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond +y is none
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! parent bond -z is none
# self-sym paint(voxel_4)
#     map_paint(parent_4 --> child_4, sym=translation, with_negation=False)
#         parent = ['+x (None),', '-x (None),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (None),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
# oops! parent bond +x is none
# oops! parent bond -x is none
# oops! child bond +y is not none, and we're not forcing
# oops! parent bond -y is none
# oops! parent bond +z is none
# oops! parent bond -z is none
#     map_paint(parent_4 --> child_4, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#         parent = ['+x (None),', '-x (None),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (None),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
# oops! parent bond -y is none
# oops! parent bond +y is none
# 	 ---> painting -4 onto voxel 4's bond -x with type structural
# 	 ---> painting 4 onto voxel 3's bond +x with type structural
# oops! parent bond +x is none
# oops! parent bond -z is none
# oops! parent bond +z is none
#     map_paint(parent_4 --> child_4, sym=270° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (None),', '-x (-4),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (-4),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
# oops! parent bond -y is none
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond +x is none
# oops! parent bond -z is none
# oops! parent bond +z is none
# 	 ---> painting 5 onto voxel 2's bond +y with type structural
# 	 ---> painting -5 onto voxel 8's bond -y with type structural
#
# --- PAINT S_BOND (5) ---
# voxel_2 ((0, 1, 0)) <---> voxel_8 ((0, -1, 0))
# self-sym paint(voxel_2)
#     map_paint(parent_2 --> child_2, sym=translation, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (5),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (-2),', '-x (-3),', '+y (5),', '-y (None),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! parent bond -y is none
# oops! parent bond +z is none
# oops! parent bond -z is none
# self-sym paint(voxel_8)
#     map_paint(parent_8 --> child_8, sym=translation, with_negation=False)
#         parent = ['+x (None),', '-x (None),', '+y (None),', '-y (-5),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (None),', '+y (None),', '-y (-5),', '+z (None),', '-z (None),']
# oops! parent bond +x is none
# oops! parent bond -x is none
# oops! parent bond +y is none
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! parent bond -z is none
#     map_paint(parent_8 --> child_8, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#         parent = ['+x (None),', '-x (None),', '+y (None),', '-y (-5),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (None),', '+y (None),', '-y (-5),', '+z (None),', '-z (None),']
# oops! parent bond -y is none
# oops! parent bond +y is none
# oops! parent bond -x is none
# 	 ---> painting -5 onto voxel 8's bond +x with type structural
# 	 ---> painting 5 onto voxel 6's bond -x with type structural
# oops! parent bond -z is none
# oops! parent bond +z is none
#     map_paint(parent_8 --> child_8, sym=270° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (-5),', '-x (None),', '+y (None),', '-y (-5),', '+z (None),', '-z (None),']
#         child = ['+x (-5),', '-x (None),', '+y (None),', '-y (-5),', '+z (None),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +y is none
# oops! parent bond -x is none
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -z is none
# oops! parent bond +z is none
# 	 ---> painting 6 onto voxel 2's bond -y with type structural
# 	 ---> painting -6 onto voxel 5's bond +y with type structural
#
# --- PAINT S_BOND (6) ---
# voxel_2 ((0, -1, 0)) <---> voxel_5 ((0, 1, 0))
# self-sym paint(voxel_2)
#     map_paint(parent_2 --> child_2, sym=translation, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (5),', '-y (6),', '+z (None),', '-z (None),']
#         child = ['+x (-2),', '-x (-3),', '+y (5),', '-y (6),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! parent bond -z is none
# self-sym paint(voxel_5)
#     map_paint(parent_5 --> child_5, sym=translation, with_negation=False)
#         parent = ['+x (None),', '-x (None),', '+y (-6),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (None),', '+y (-6),', '-y (None),', '+z (None),', '-z (None),']
# oops! parent bond +x is none
# oops! parent bond -x is none
# oops! child bond +y is not none, and we're not forcing
# oops! parent bond -y is none
# oops! parent bond +z is none
# oops! parent bond -z is none
# 	 ---> painting 7 onto voxel 4's bond +x with type structural
# 	 ---> painting -7 onto voxel 5's bond -x with type structural
#
# --- PAINT S_BOND (7) ---
# voxel_4 ((1, 0, 0)) <---> voxel_5 ((-1, 0, 0))
# self-sym paint(voxel_4)
#     map_paint(parent_4 --> child_4, sym=translation, with_negation=False)
#         parent = ['+x (7),', '-x (-4),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (7),', '-x (-4),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! parent bond -y is none
# oops! parent bond +z is none
# oops! parent bond -z is none
#     map_paint(parent_4 --> child_4, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#         parent = ['+x (7),', '-x (-4),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (7),', '-x (-4),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
# 	 ---> painting 7 onto voxel 4's bond -y with type structural
# 	 ---> painting -7 onto voxel 7's bond +y with type structural
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond +x is none
# oops! parent bond -z is none
# oops! parent bond +z is none
#     map_paint(parent_4 --> child_4, sym=270° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (None),', '-z (None),']
#         child = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (None),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -z is none
# oops! parent bond +z is none
# self-sym paint(voxel_5)
#     map_paint(parent_5 --> child_5, sym=translation, with_negation=False)
#         parent = ['+x (None),', '-x (-7),', '+y (-6),', '-y (None),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (-7),', '+y (-6),', '-y (None),', '+z (None),', '-z (None),']
# oops! parent bond +x is none
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! parent bond -y is none
# oops! parent bond +z is none
# oops! parent bond -z is none
# 	 ---> painting 8 onto voxel 5's bond -y with type structural
# 	 ---> painting -8 onto voxel 8's bond +y with type structural
#
# --- PAINT S_BOND (8) ---
# voxel_5 ((0, -1, 0)) <---> voxel_8 ((0, 1, 0))
# self-sym paint(voxel_5)
#     map_paint(parent_5 --> child_5, sym=translation, with_negation=False)
#         parent = ['+x (None),', '-x (-7),', '+y (-6),', '-y (8),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (-7),', '+y (-6),', '-y (8),', '+z (None),', '-z (None),']
# oops! parent bond +x is none
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! parent bond -z is none
# self-sym paint(voxel_8)
#     map_paint(parent_8 --> child_8, sym=translation, with_negation=False)
#         parent = ['+x (-5),', '-x (None),', '+y (-8),', '-y (-5),', '+z (None),', '-z (None),']
#         child = ['+x (-5),', '-x (None),', '+y (-8),', '-y (-5),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -x is none
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! parent bond -z is none
#     map_paint(parent_8 --> child_8, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#         parent = ['+x (-5),', '-x (None),', '+y (-8),', '-y (-5),', '+z (None),', '-z (None),']
#         child = ['+x (-5),', '-x (None),', '+y (-8),', '-y (-5),', '+z (None),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +y is none
# 	 ---> painting -8 onto voxel 8's bond -x with type structural
# 	 ---> painting 8 onto voxel 7's bond +x with type structural
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -z is none
# oops! parent bond +z is none
#     map_paint(parent_8 --> child_8, sym=270° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (-5),', '-x (-8),', '+y (-8),', '-y (-5),', '+z (None),', '-z (None),']
#         child = ['+x (-5),', '-x (-8),', '+y (-8),', '-y (-5),', '+z (None),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -z is none
# oops! parent bond +z is none
#
# ===== STARTING COMP_PAINT_LATTICE =====
#
#
# LOOP 0: Between voxel1 (0)'s bond +z and voxel2 (27)'s bond -z
# ---
# MESOPARENT: Only found str_mp 0 and it IS voxel1. Flipping complementarity when mapping.
#     map_paint(parent_0 --> child_27, sym=180° X-axis, with_negation=True)
#         parent = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (None),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# 	 ---> painting 1 onto voxel 27's bond +x with type structural
# 	 ---> painting -1 onto voxel 28's bond -x with type structural
# 	 ---> painting 2 onto voxel 27's bond -x with type structural
# 	 ---> painting -2 onto voxel 29's bond +x with type structural
# 	 ---> painting 2 onto voxel 27's bond -y with type structural
# 	 ---> painting -2 onto voxel 30's bond +y with type structural
# 	 ---> painting 1 onto voxel 27's bond +y with type structural
# 	 ---> painting -1 onto voxel 33's bond -y with type structural
# oops! parent bond -z is none
# oops! parent bond +z is none
#
# --- PAINT complementary BOND (9) ---
# voxel_0 ((0, 0, 1)) <---> voxel_27 ((0, 0, -1))
#
# 	 ---> painting 9 onto voxel 0's bond +z with type complementary
# 	 ---> painting -9 onto voxel 27's bond -z with type complementary
# self-sym paint(voxel_0)
#     map_paint(parent_0 --> child_0, sym=translation, with_negation=False)
#         parent = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (9),', '-z (None),']
#         child = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (9),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! parent bond -z is none
#     map_paint(parent_0 --> child_0, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#         parent = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (9),', '-z (None),']
#         child = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (9),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# 	 ---> painting 9 onto voxel 0's bond -z with type complementary
# 	 ---> painting -9 onto voxel 9's bond +z with type complementary
# oops! parent bond +z is none
#     map_paint(parent_0 --> child_0, sym=270° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (9),', '-z (9),']
#         child = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (9),', '-z (9),']
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# self-sym paint(voxel_27)
#     map_paint(parent_27 --> child_27, sym=translation, with_negation=False)
#         parent = ['+x (1),', '-x (2),', '+y (1),', '-y (2),', '+z (None),', '-z (-9),']
#         child = ['+x (1),', '-x (2),', '+y (1),', '-y (2),', '+z (None),', '-z (-9),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! child bond -z is not none, and we're not forcing
#     map_paint(parent_27 --> child_27, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#         parent = ['+x (1),', '-x (2),', '+y (1),', '-y (2),', '+z (None),', '-z (-9),']
#         child = ['+x (1),', '-x (2),', '+y (1),', '-y (2),', '+z (None),', '-z (-9),']
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond -z is none
# 	 ---> painting -9 onto voxel 27's bond +z with type complementary
# 	 ---> painting 9 onto voxel 18's bond -z with type complementary
#     map_paint(parent_27 --> child_27, sym=90° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (1),', '-x (2),', '+y (1),', '-y (2),', '+z (-9),', '-z (-9),']
#         child = ['+x (1),', '-x (2),', '+y (1),', '-y (2),', '+z (-9),', '-z (-9),']
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# mapping child voxel_27 back onto parent voxel_0
#     map_paint(parent_27 --> child_0, sym=180° X-axis, with_negation=True)
#         parent = ['+x (1),', '-x (2),', '+y (1),', '-y (2),', '+z (-9),', '-z (-9),']
#         child = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (9),', '-z (9),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
#
# LOOP 1: Between voxel1 (1)'s bond +y and voxel2 (7)'s bond -y
# ---
# MESOPARENT: Only found str_mp 5 and it's not voxel1. (No flip comp)
#     map_paint(parent_5 --> child_7, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#         parent = ['+x (None),', '-x (-7),', '+y (-6),', '-y (8),', '+z (None),', '-z (None),']
#         child = ['+x (8),', '-x (None),', '+y (-7),', '-y (None),', '+z (None),', '-z (None),']
# oops! parent bond -y is none
# oops! child bond +y is not none, and we're not forcing
# 	 ---> painting -6 onto voxel 7's bond -x with type structural
# 	 ---> painting 6 onto voxel 6's bond +x with type structural
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond -z is none
# oops! parent bond +z is none
#
# --- PAINT structural BOND (10) ---
# voxel_1 ((0, 1, 0)) <---> voxel_7 ((0, -1, 0))
#
# 	 ---> painting 10 onto voxel 1's bond +y with type structural
# 	 ---> painting -10 onto voxel 7's bond -y with type structural
# self-sym paint(voxel_1)
#     map_paint(parent_1 --> child_1, sym=translation, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (10),', '-y (4),', '+z (None),', '-z (None),']
#         child = ['+x (3),', '-x (-1),', '+y (10),', '-y (4),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! parent bond -z is none
# self-sym paint(voxel_7)
#     map_paint(parent_7 --> child_7, sym=translation, with_negation=False)
#         parent = ['+x (8),', '-x (-6),', '+y (-7),', '-y (-10),', '+z (None),', '-z (None),']
#         child = ['+x (8),', '-x (-6),', '+y (-7),', '-y (-10),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! parent bond -z is none
# mapping child voxel_7 back onto parent voxel_5
#
# LOOP 2: Between voxel1 (1)'s bond +z and voxel2 (28)'s bond -z
# ---
# MESOPARENT: Only found str_mp 1 and it IS voxel1. Flipping complementarity when mapping.
#     map_paint(parent_1 --> child_28, sym=180° X-axis, with_negation=True)
#         parent = ['+x (3),', '-x (-1),', '+y (10),', '-y (4),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (-1),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# 	 ---> painting 3 onto voxel 28's bond +x with type structural
# 	 ---> painting -3 onto voxel 29's bond -x with type structural
# oops! child bond -x is not none, and we're not forcing
# 	 ---> painting 10 onto voxel 28's bond -y with type structural
# 	 ---> painting -10 onto voxel 31's bond +y with type structural
# 	 ---> painting 4 onto voxel 28's bond +y with type structural
# 	 ---> painting -4 onto voxel 34's bond -y with type structural
# oops! parent bond -z is none
# oops! parent bond +z is none
#
# --- PAINT complementary BOND (11) ---
# voxel_1 ((0, 0, 1)) <---> voxel_28 ((0, 0, -1))
#
# 	 ---> painting 11 onto voxel 1's bond +z with type complementary
# 	 ---> painting -11 onto voxel 28's bond -z with type complementary
# self-sym paint(voxel_1)
#     map_paint(parent_1 --> child_1, sym=translation, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (10),', '-y (4),', '+z (11),', '-z (None),']
#         child = ['+x (3),', '-x (-1),', '+y (10),', '-y (4),', '+z (11),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! parent bond -z is none
# self-sym paint(voxel_28)
#     map_paint(parent_28 --> child_28, sym=translation, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (4),', '-y (10),', '+z (None),', '-z (-11),']
#         child = ['+x (3),', '-x (-1),', '+y (4),', '-y (10),', '+z (None),', '-z (-11),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! child bond -z is not none, and we're not forcing
# mapping child voxel_28 back onto parent voxel_1
#     map_paint(parent_28 --> child_1, sym=180° X-axis, with_negation=True)
#         parent = ['+x (3),', '-x (-1),', '+y (4),', '-y (10),', '+z (None),', '-z (-11),']
#         child = ['+x (3),', '-x (-1),', '+y (10),', '-y (4),', '+z (11),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! parent bond -z is none
# oops! child bond +z is not none, and we're not forcing
#
# LOOP 3: Between voxel1 (1)'s bond -z and voxel2 (10)'s bond +z
# ---
# MESOPARENT: Only found str_mp 2 and it's not voxel1. (No flip comp)
#     map_paint(parent_2 --> child_10, sym=180° Y-axis, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (5),', '-y (6),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (None),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# 	 ---> painting -2 onto voxel 10's bond -x with type structural
# 	 ---> painting 2 onto voxel 9's bond +x with type structural
# 	 ---> painting -3 onto voxel 10's bond +x with type structural
# 	 ---> painting 3 onto voxel 11's bond -x with type structural
# 	 ---> painting 5 onto voxel 10's bond +y with type structural
# 	 ---> painting -5 onto voxel 16's bond -y with type structural
# 	 ---> painting 6 onto voxel 10's bond -y with type structural
# 	 ---> painting -6 onto voxel 13's bond +y with type structural
# oops! parent bond -z is none
# oops! parent bond +z is none
#
# --- PAINT structural BOND (12) ---
# voxel_1 ((0, 0, -1)) <---> voxel_10 ((0, 0, 1))
#
# 	 ---> painting 12 onto voxel 1's bond -z with type structural
# 	 ---> painting -12 onto voxel 10's bond +z with type structural
# self-sym paint(voxel_1)
#     map_paint(parent_1 --> child_1, sym=translation, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (10),', '-y (4),', '+z (11),', '-z (12),']
#         child = ['+x (3),', '-x (-1),', '+y (10),', '-y (4),', '+z (11),', '-z (12),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# self-sym paint(voxel_10)
#     map_paint(parent_10 --> child_10, sym=translation, with_negation=False)
#         parent = ['+x (-3),', '-x (-2),', '+y (5),', '-y (6),', '+z (-12),', '-z (None),']
#         child = ['+x (-3),', '-x (-2),', '+y (5),', '-y (6),', '+z (-12),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! parent bond -z is none
# mapping child voxel_10 back onto parent voxel_2
#
# LOOP 4: Between voxel1 (2)'s bond +z and voxel2 (29)'s bond -z
# ---
# MESOPARENT: Only found str_mp 2 and it IS voxel1. Flipping complementarity when mapping.
#     map_paint(parent_2 --> child_29, sym=180° X-axis, with_negation=True)
#         parent = ['+x (-2),', '-x (-3),', '+y (5),', '-y (6),', '+z (None),', '-z (None),']
#         child = ['+x (-2),', '-x (-3),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# 	 ---> painting 5 onto voxel 29's bond -y with type structural
# 	 ---> painting -5 onto voxel 32's bond +y with type structural
# 	 ---> painting 6 onto voxel 29's bond +y with type structural
# 	 ---> painting -6 onto voxel 35's bond -y with type structural
# oops! parent bond -z is none
# oops! parent bond +z is none
#
# --- PAINT complementary BOND (13) ---
# voxel_2 ((0, 0, 1)) <---> voxel_29 ((0, 0, -1))
#
# 	 ---> painting 13 onto voxel 2's bond +z with type complementary
# 	 ---> painting -13 onto voxel 29's bond -z with type complementary
# self-sym paint(voxel_2)
#     map_paint(parent_2 --> child_2, sym=translation, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (5),', '-y (6),', '+z (13),', '-z (None),']
#         child = ['+x (-2),', '-x (-3),', '+y (5),', '-y (6),', '+z (13),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! parent bond -z is none
# self-sym paint(voxel_29)
#     map_paint(parent_29 --> child_29, sym=translation, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (6),', '-y (5),', '+z (None),', '-z (-13),']
#         child = ['+x (-2),', '-x (-3),', '+y (6),', '-y (5),', '+z (None),', '-z (-13),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! child bond -z is not none, and we're not forcing
# mapping child voxel_29 back onto parent voxel_2
#     map_paint(parent_29 --> child_2, sym=180° X-axis, with_negation=True)
#         parent = ['+x (-2),', '-x (-3),', '+y (6),', '-y (5),', '+z (None),', '-z (-13),']
#         child = ['+x (-2),', '-x (-3),', '+y (5),', '-y (6),', '+z (13),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! parent bond -z is none
# oops! child bond +z is not none, and we're not forcing
#
# LOOP 5: Between voxel1 (2)'s bond -z and voxel2 (11)'s bond +z
# ---
# MESOPARENT: Found comp_mp 28!
#     map_paint(parent_28 --> child_11, sym=180° Z-axis, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (4),', '-y (10),', '+z (None),', '-z (-11),']
#         child = ['+x (None),', '-x (3),', '+y (None),', '-y (None),', '+z (None),', '-z (None),']
# oops! child bond -x is not none, and we're not forcing
# 	 ---> painting -1 onto voxel 11's bond +x with type structural
# 	 ---> painting 1 onto voxel 9's bond -x with type structural
# 	 ---> painting 4 onto voxel 11's bond -y with type structural
# 	 ---> painting -4 onto voxel 14's bond +y with type structural
# 	 ---> painting 10 onto voxel 11's bond +y with type structural
# 	 ---> painting -10 onto voxel 17's bond -y with type structural
# oops! parent bond +z is none
# 	 ---> painting -11 onto voxel 11's bond -z with type complementary
# 	 ---> painting 11 onto voxel 20's bond +z with type complementary
#
# --- PAINT structural BOND (14) ---
# voxel_2 ((0, 0, -1)) <---> voxel_11 ((0, 0, 1))
#
# 	 ---> painting 14 onto voxel 2's bond -z with type structural
# 	 ---> painting -14 onto voxel 11's bond +z with type structural
# self-sym paint(voxel_2)
#     map_paint(parent_2 --> child_2, sym=translation, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (5),', '-y (6),', '+z (13),', '-z (14),']
#         child = ['+x (-2),', '-x (-3),', '+y (5),', '-y (6),', '+z (13),', '-z (14),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# self-sym paint(voxel_11)
#     map_paint(parent_11 --> child_11, sym=translation, with_negation=False)
#         parent = ['+x (-1),', '-x (3),', '+y (10),', '-y (4),', '+z (-14),', '-z (-11),']
#         child = ['+x (-1),', '-x (3),', '+y (10),', '-y (4),', '+z (-14),', '-z (-11),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# mapping child voxel_11 back onto parent voxel_28
#
# LOOP 6: Between voxel1 (4)'s bond +z and voxel2 (31)'s bond -z
# ---
# MESOPARENT: Only found str_mp 5 and it's not voxel1. (No flip comp)
#     map_paint(parent_5 --> child_31, sym=90° Z-axis, with_negation=False)
#         parent = ['+x (None),', '-x (-7),', '+y (-6),', '-y (8),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (None),', '+y (-10),', '-y (None),', '+z (None),', '-z (None),']
# oops! parent bond +y is none
# 	 ---> painting -7 onto voxel 31's bond -y with type structural
# 	 ---> painting 7 onto voxel 34's bond +y with type structural
# 	 ---> painting -6 onto voxel 31's bond -x with type structural
# 	 ---> painting 6 onto voxel 30's bond +x with type structural
# 	 ---> painting 8 onto voxel 31's bond +x with type structural
# 	 ---> painting -8 onto voxel 32's bond -x with type structural
# oops! parent bond +z is none
# oops! parent bond -z is none
#
# --- PAINT structural BOND (15) ---
# voxel_4 ((0, 0, 1)) <---> voxel_31 ((0, 0, -1))
#
# 	 ---> painting 15 onto voxel 4's bond +z with type structural
# 	 ---> painting -15 onto voxel 31's bond -z with type structural
# self-sym paint(voxel_4)
#     map_paint(parent_4 --> child_4, sym=translation, with_negation=False)
#         parent = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (15),', '-z (None),']
#         child = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (15),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! parent bond -z is none
#     map_paint(parent_4 --> child_4, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#         parent = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (15),', '-z (None),']
#         child = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (15),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# 	 ---> painting 15 onto voxel 4's bond -z with type structural
# 	 ---> painting -15 onto voxel 13's bond +z with type structural
# oops! parent bond +z is none
#     map_paint(parent_4 --> child_4, sym=270° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
#         child = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# self-sym paint(voxel_31)
#     map_paint(parent_31 --> child_31, sym=translation, with_negation=False)
#         parent = ['+x (8),', '-x (-6),', '+y (-10),', '-y (-7),', '+z (None),', '-z (-15),']
#         child = ['+x (8),', '-x (-6),', '+y (-10),', '-y (-7),', '+z (None),', '-z (-15),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! child bond -z is not none, and we're not forcing
# mapping child voxel_31 back onto parent voxel_5
#
# LOOP 7: Between voxel1 (5)'s bond +x and voxel2 (3)'s bond -x
# ---
# MESOPARENT: Found comp_mp 28!
#     map_paint(parent_28 --> child_3, sym=90° Z-axis, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (4),', '-y (10),', '+z (None),', '-z (-11),']
#         child = ['+x (4),', '-x (None),', '+y (-1),', '-y (None),', '+z (None),', '-z (None),']
# oops! child bond +y is not none, and we're not forcing
# 	 ---> painting -1 onto voxel 3's bond -y with type structural
# 	 ---> painting 1 onto voxel 6's bond +y with type structural
# 	 ---> painting 4 onto voxel 3's bond -x with type structural
# 	 ---> painting -4 onto voxel 5's bond +x with type structural
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond +z is none
# 	 ---> painting -11 onto voxel 3's bond -z with type complementary
# 	 ---> painting 11 onto voxel 12's bond +z with type complementary
# self-sym paint(voxel_5)
#     map_paint(parent_5 --> child_5, sym=translation, with_negation=False)
#         parent = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (None),', '-z (None),']
#         child = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (None),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! parent bond -z is none
# self-sym paint(voxel_3)
#     map_paint(parent_3 --> child_3, sym=translation, with_negation=False)
#         parent = ['+x (4),', '-x (4),', '+y (-1),', '-y (-1),', '+z (None),', '-z (-11),']
#         child = ['+x (4),', '-x (4),', '+y (-1),', '-y (-1),', '+z (None),', '-z (-11),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! child bond -z is not none, and we're not forcing
# mapping child voxel_3 back onto parent voxel_28
#     map_paint(parent_3 --> child_28, sym=90° Z-axis, with_negation=False)
#         parent = ['+x (4),', '-x (4),', '+y (-1),', '-y (-1),', '+z (None),', '-z (-11),']
#         child = ['+x (3),', '-x (-1),', '+y (4),', '-y (10),', '+z (None),', '-z (-11),']
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! parent bond +z is none
# oops! child bond -z is not none, and we're not forcing
#
# LOOP 8: Between voxel1 (5)'s bond +z and voxel2 (32)'s bond -z
# ---
# MESOPARENT: Only found str_mp 8 and it's not voxel1. (No flip comp)
#     map_paint(parent_8 --> child_32, sym=180° X-axis, with_negation=False)
#         parent = ['+x (-5),', '-x (-8),', '+y (-8),', '-y (-5),', '+z (None),', '-z (None),']
#         child = ['+x (None),', '-x (-8),', '+y (-5),', '-y (None),', '+z (None),', '-z (None),']
# 	 ---> painting -5 onto voxel 32's bond +x with type structural
# 	 ---> painting 5 onto voxel 30's bond -x with type structural
# oops! child bond -x is not none, and we're not forcing
# 	 ---> painting -8 onto voxel 32's bond -y with type structural
# 	 ---> painting 8 onto voxel 35's bond +y with type structural
# oops! child bond +y is not none, and we're not forcing
# oops! parent bond -z is none
# oops! parent bond +z is none
#
# --- PAINT structural BOND (16) ---
# voxel_5 ((0, 0, 1)) <---> voxel_32 ((0, 0, -1))
#
# 	 ---> painting 16 onto voxel 5's bond +z with type structural
# 	 ---> painting -16 onto voxel 32's bond -z with type structural
# self-sym paint(voxel_5)
#     map_paint(parent_5 --> child_5, sym=translation, with_negation=False)
#         parent = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (16),', '-z (None),']
#         child = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (16),', '-z (None),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! parent bond -z is none
# self-sym paint(voxel_32)
#     map_paint(parent_32 --> child_32, sym=translation, with_negation=False)
#         parent = ['+x (-5),', '-x (-8),', '+y (-5),', '-y (-8),', '+z (None),', '-z (-16),']
#         child = ['+x (-5),', '-x (-8),', '+y (-5),', '-y (-8),', '+z (None),', '-z (-16),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! parent bond +z is none
# oops! child bond -z is not none, and we're not forcing
#     map_paint(parent_32 --> child_32, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#         parent = ['+x (-5),', '-x (-8),', '+y (-5),', '-y (-8),', '+z (None),', '-z (-16),']
#         child = ['+x (-5),', '-x (-8),', '+y (-5),', '-y (-8),', '+z (None),', '-z (-16),']
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond -z is none
# 	 ---> painting -16 onto voxel 32's bond +z with type structural
# 	 ---> painting 16 onto voxel 23's bond -z with type structural
#     map_paint(parent_32 --> child_32, sym=90° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (-5),', '-x (-8),', '+y (-5),', '-y (-8),', '+z (-16),', '-z (-16),']
#         child = ['+x (-5),', '-x (-8),', '+y (-5),', '-y (-8),', '+z (-16),', '-z (-16),']
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# mapping child voxel_32 back onto parent voxel_8
#
# LOOP 9: Between voxel1 (5)'s bond -z and voxel2 (14)'s bond +z
# ---
# MESOPARENT: Only found str_mp 4 and it's not voxel1. (No flip comp)
#     map_paint(parent_4 --> child_14, sym=180° Y-axis, with_negation=False)
#         parent = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
#         child = ['+x (None),', '-x (None),', '+y (-4),', '-y (None),', '+z (None),', '-z (None),']
# 	 ---> painting 7 onto voxel 14's bond -x with type structural
# 	 ---> painting -7 onto voxel 13's bond +x with type structural
# 	 ---> painting -4 onto voxel 14's bond +x with type structural
# 	 ---> painting 4 onto voxel 12's bond -x with type structural
# oops! child bond +y is not none, and we're not forcing
# 	 ---> painting 7 onto voxel 14's bond -y with type structural
# 	 ---> painting -7 onto voxel 17's bond +y with type structural
# 	 ---> painting 15 onto voxel 14's bond -z with type structural
# 	 ---> painting -15 onto voxel 23's bond +z with type structural
# 	 ---> painting 15 onto voxel 14's bond +z with type structural
# 	 ---> painting -15 onto voxel 5's bond -z with type structural
# self-sym paint(voxel_5)
#     map_paint(parent_5 --> child_5, sym=translation, with_negation=False)
#         parent = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (16),', '-z (-15),']
#         child = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (16),', '-z (-15),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# self-sym paint(voxel_14)
#     map_paint(parent_14 --> child_14, sym=translation, with_negation=False)
#         parent = ['+x (-4),', '-x (7),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
#         child = ['+x (-4),', '-x (7),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
#     map_paint(parent_14 --> child_14, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#         parent = ['+x (-4),', '-x (7),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
#         child = ['+x (-4),', '-x (7),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
#     map_paint(parent_14 --> child_14, sym=90° Z-axis + 180° X-axis, with_negation=False)
#         parent = ['+x (-4),', '-x (7),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
#         child = ['+x (-4),', '-x (7),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# ...
#     map_paint(parent_4 --> child_14, sym=180° Y-axis, with_negation=False)
#         parent = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
#         child = ['+x (-4),', '-x (7),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# checking partner 16
# checking partner 17
# checking partner 12
# checking partner 9
# checking partner 6
# 6 has sym and mesotype structural
# found partner voxel6 with type structural - setting map_variant to 29
# both str_mp 2 and comp_mp 29 exist, mapping 29 onto voxel 15
#     map_paint(parent_29 --> child_15, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (6),', '-y (5),', '+z (None),', '-z (-13),']
#         child = ['+x (None),', '-x (None),', '+y (-3),', '-y (-2),', '+z (-13),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# 	 ---> painting 6 onto voxel 15's bond -x with type structural
# 	 ---> painting -6 onto voxel 17's bond +x with type structural
# 	 ---> painting 5 onto voxel 15's bond +x with type structural
# 	 ---> painting -5 onto voxel 16's bond -x with type structural
# oops! parent bond -z is none
# oops! child bond +z is not none, and we're not forcing
# only str_mp 8 exists, mapping onto voxel 16
#     map_paint(parent_8 --> child_16, sym=180° Y-axis, with_negation=False)
#         parent = ['+x (-5),', '-x (-8),', '+y (-8),', '-y (-5),', '+z (-16),', '-z (-16),']
#         child = ['+x (None),', '-x (-5),', '+y (-8),', '-y (-5),', '+z (-16),', '-z (None),']
# oops! child bond -x is not none, and we're not forcing
# 	 ---> painting -8 onto voxel 16's bond +x with type structural
# 	 ---> painting 8 onto voxel 17's bond -x with type structural
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# 	 ---> painting -16 onto voxel 16's bond -z with type structural
# 	 ---> painting 16 onto voxel 25's bond +z with type structural
# oops! child bond +z is not none, and we're not forcing
# only str_mp 5 exists, mapping onto voxel 17
#     map_paint(parent_5 --> child_17, sym=270° Z-axis, with_negation=False)
#         parent = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (16),', '-z (-15),']
#         child = ['+x (-6),', '-x (8),', '+y (-7),', '-y (-10),', '+z (16),', '-z (None),']
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# 	 ---> painting -15 onto voxel 17's bond -z with type structural
# 	 ---> painting 15 onto voxel 26's bond +z with type structural
# checking partner 19
# checking partner 20
# checking partner 24
# checking partner 21
# checking partner 9
# 9 has sym and mesotype complementary
# found partner voxel9 with type complementary - setting map_variant to 0
# both str_mp 0 and comp_mp 27 exist, mapping 0 onto voxel 18
#     map_paint(parent_0 --> child_18, sym=180° Z-axis, with_negation=False)
#         parent = ['+x (1),', '-x (2),', '+y (2),', '-y (1),', '+z (9),', '-z (9),']
#         child = ['+x (None),', '-x (None),', '+y (None),', '-y (None),', '+z (9),', '-z (9),']
# 	 ---> painting 1 onto voxel 18's bond -x with type structural
# 	 ---> painting -1 onto voxel 20's bond +x with type structural
# 	 ---> painting 2 onto voxel 18's bond +x with type structural
# 	 ---> painting -2 onto voxel 19's bond -x with type structural
# 	 ---> painting 2 onto voxel 18's bond -y with type structural
# 	 ---> painting -2 onto voxel 21's bond +y with type structural
# 	 ---> painting 1 onto voxel 18's bond +y with type structural
# 	 ---> painting -1 onto voxel 24's bond -y with type structural
# oops! child bond +z is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# checking partner 20
# checking partner 18
# checking partner 25
# checking partner 22
# checking partner 10
# 10 has sym and mesotype structural
# found partner voxel10 with type structural - setting map_variant to 29
# both str_mp 2 and comp_mp 29 exist, mapping 29 onto voxel 19
#     map_paint(parent_29 --> child_19, sym=180° Y-axis, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (6),', '-y (5),', '+z (None),', '-z (-13),']
#         child = ['+x (None),', '-x (-2),', '+y (None),', '-y (None),', '+z (-13),', '-z (None),']
# oops! child bond -x is not none, and we're not forcing
# 	 ---> painting -3 onto voxel 19's bond +x with type structural
# 	 ---> painting 3 onto voxel 20's bond -x with type structural
# 	 ---> painting 6 onto voxel 19's bond +y with type structural
# 	 ---> painting -6 onto voxel 25's bond -y with type structural
# 	 ---> painting 5 onto voxel 19's bond -y with type structural
# 	 ---> painting -5 onto voxel 22's bond +y with type structural
# oops! parent bond -z is none
# oops! child bond +z is not none, and we're not forcing
# checking partner 18
# checking partner 19
# checking partner 26
# checking partner 23
# checking partner 11
# 11 has sym and mesotype structural
# found partner voxel11 with type structural - setting map_variant to 28
# both str_mp 1 and comp_mp 28 exist, mapping 28 onto voxel 20
#     map_paint(parent_28 --> child_20, sym=180° Y-axis, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (4),', '-y (10),', '+z (None),', '-z (-11),']
#         child = ['+x (-1),', '-x (3),', '+y (None),', '-y (None),', '+z (11),', '-z (None),']
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# 	 ---> painting 4 onto voxel 20's bond +y with type structural
# 	 ---> painting -4 onto voxel 26's bond -y with type structural
# 	 ---> painting 10 onto voxel 20's bond -y with type structural
# 	 ---> painting -10 onto voxel 23's bond +y with type structural
# oops! parent bond -z is none
# oops! child bond +z is not none, and we're not forcing
# checking partner 22
# checking partner 23
# checking partner 18
# checking partner 24
# checking partner 12
# checking partner 30
# 30 has sym and mesotype None
# both str_mp 2 and comp_mp 29 exist, mapping 2 onto voxel 21
#     map_paint(parent_2 --> child_21, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (5),', '-y (6),', '+z (13),', '-z (14),']
#         child = ['+x (None),', '-x (None),', '+y (-2),', '-y (None),', '+z (None),', '-z (None),']
# oops! child bond +y is not none, and we're not forcing
# 	 ---> painting -3 onto voxel 21's bond -y with type structural
# 	 ---> painting 3 onto voxel 24's bond +y with type structural
# 	 ---> painting 5 onto voxel 21's bond +x with type structural
# 	 ---> painting -5 onto voxel 22's bond -x with type structural
# 	 ---> painting 6 onto voxel 21's bond -x with type structural
# 	 ---> painting -6 onto voxel 23's bond +x with type structural
# 	 ---> painting 13 onto voxel 21's bond -z with type complementary
# 	 ---> painting -13 onto voxel 30's bond +z with type complementary
# 	 ---> painting 14 onto voxel 21's bond +z with type structural
# 	 ---> painting -14 onto voxel 12's bond -z with type structural
# only str_mp 8 exists, mapping onto voxel 22
#     map_paint(parent_8 --> child_22, sym=180° Z-axis, with_negation=False)
#         parent = ['+x (-5),', '-x (-8),', '+y (-8),', '-y (-5),', '+z (-16),', '-z (-16),']
#         child = ['+x (None),', '-x (-5),', '+y (-5),', '-y (None),', '+z (-16),', '-z (None),']
# oops! child bond -x is not none, and we're not forcing
# 	 ---> painting -8 onto voxel 22's bond +x with type structural
# 	 ---> painting 8 onto voxel 23's bond -x with type structural
# 	 ---> painting -8 onto voxel 22's bond -y with type structural
# 	 ---> painting 8 onto voxel 25's bond +y with type structural
# oops! child bond +y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# 	 ---> painting -16 onto voxel 22's bond -z with type structural
# 	 ---> painting 16 onto voxel 31's bond +z with type structural
# only str_mp 5 exists, mapping onto voxel 23
#     map_paint(parent_5 --> child_23, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#         parent = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (16),', '-z (-15),']
#         child = ['+x (-6),', '-x (8),', '+y (-10),', '-y (None),', '+z (-15),', '-z (16),']
# oops! child bond +y is not none, and we're not forcing
# 	 ---> painting -7 onto voxel 23's bond -y with type structural
# 	 ---> painting 7 onto voxel 26's bond +y with type structural
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# checking partner 25
# checking partner 26
# checking partner 21
# checking partner 18
# checking partner 15
# checking partner 33
# 33 has sym and mesotype None
# both str_mp 1 and comp_mp 28 exist, mapping 1 onto voxel 24
#     map_paint(parent_1 --> child_24, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (10),', '-y (4),', '+z (11),', '-z (12),']
#         child = ['+x (None),', '-x (None),', '+y (3),', '-y (-1),', '+z (None),', '-z (None),']
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# 	 ---> painting 10 onto voxel 24's bond +x with type structural
# 	 ---> painting -10 onto voxel 25's bond -x with type structural
# 	 ---> painting 4 onto voxel 24's bond -x with type structural
# 	 ---> painting -4 onto voxel 26's bond +x with type structural
# 	 ---> painting 11 onto voxel 24's bond -z with type complementary
# 	 ---> painting -11 onto voxel 33's bond +z with type complementary
# 	 ---> painting 12 onto voxel 24's bond +z with type structural
# 	 ---> painting -12 onto voxel 15's bond -z with type structural
# only str_mp 5 exists, mapping onto voxel 25
#     map_paint(parent_5 --> child_25, sym=180° Z-axis, with_negation=False)
#         parent = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (16),', '-z (-15),']
#         child = ['+x (None),', '-x (-10),', '+y (8),', '-y (-6),', '+z (16),', '-z (None),']
# oops! child bond -x is not none, and we're not forcing
# 	 ---> painting -7 onto voxel 25's bond +x with type structural
# 	 ---> painting 7 onto voxel 26's bond -x with type structural
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# 	 ---> painting -15 onto voxel 25's bond -z with type structural
# 	 ---> painting 15 onto voxel 34's bond +z with type structural
# only str_mp 4 exists, mapping onto voxel 26
#     map_paint(parent_4 --> child_26, sym=180° Z-axis, with_negation=False)
#         parent = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
#         child = ['+x (-4),', '-x (7),', '+y (7),', '-y (-4),', '+z (15),', '-z (15),']
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# skipping 27, already in mesovoxel
# skipping 28, already in mesovoxel
# skipping 29, already in mesovoxel
# checking partner 31
# checking partner 32
# checking partner 27
# checking partner 33
# checking partner 21
# 21 has sym and mesotype structural
# found partner voxel21 with type structural - setting map_variant to 29
# both str_mp 2 and comp_mp 29 exist, mapping 29 onto voxel 30
#     map_paint(parent_29 --> child_30, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#         parent = ['+x (-2),', '-x (-3),', '+y (6),', '-y (5),', '+z (None),', '-z (-13),']
#         child = ['+x (6),', '-x (5),', '+y (-2),', '-y (None),', '+z (-13),', '-z (-12),']
# oops! child bond +y is not none, and we're not forcing
# 	 ---> painting -3 onto voxel 30's bond -y with type structural
# 	 ---> painting 3 onto voxel 33's bond +y with type structural
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond -z is none
# oops! child bond +z is not none, and we're not forcing
# only str_mp 5 exists, mapping onto voxel 31
#     map_paint(parent_5 --> child_31, sym=90° Z-axis, with_negation=False)
#         parent = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (16),', '-z (-15),']
#         child = ['+x (8),', '-x (-6),', '+y (-10),', '-y (-7),', '+z (16),', '-z (-15),']
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond +x is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# only str_mp 8 exists, mapping onto voxel 32
#     map_paint(parent_8 --> child_32, sym=180° X-axis, with_negation=False)
#         parent = ['+x (-5),', '-x (-8),', '+y (-8),', '-y (-5),', '+z (-16),', '-z (-16),']
#         child = ['+x (-5),', '-x (-8),', '+y (-5),', '-y (-8),', '+z (-16),', '-z (-16),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# checking partner 34
# checking partner 35
# checking partner 30
# checking partner 27
# checking partner 24
# 24 has sym and mesotype structural
# found partner voxel24 with type structural - setting map_variant to 28
# both str_mp 1 and comp_mp 28 exist, mapping 28 onto voxel 33
#     map_paint(parent_28 --> child_33, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#         parent = ['+x (3),', '-x (-1),', '+y (4),', '-y (10),', '+z (None),', '-z (-11),']
#         child = ['+x (None),', '-x (4),', '+y (3),', '-y (-1),', '+z (-11),', '-z (-14),']
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# 	 ---> painting 4 onto voxel 33's bond +x with type structural
# 	 ---> painting -4 onto voxel 34's bond -x with type structural
# oops! child bond -x is not none, and we're not forcing
# oops! parent bond -z is none
# oops! child bond +z is not none, and we're not forcing
# only str_mp 4 exists, mapping onto voxel 34
#     map_paint(parent_4 --> child_34, sym=180° X-axis, with_negation=False)
#         parent = ['+x (7),', '-x (-4),', '+y (-4),', '-y (7),', '+z (15),', '-z (15),']
#         child = ['+x (7),', '-x (-4),', '+y (7),', '-y (-4),', '+z (15),', '-z (15),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing
# only str_mp 5 exists, mapping onto voxel 35
#     map_paint(parent_5 --> child_35, sym=180° X-axis, with_negation=False)
#         parent = ['+x (-4),', '-x (-7),', '+y (-6),', '-y (8),', '+z (16),', '-z (-15),']
#         child = ['+x (-4),', '-x (-7),', '+y (8),', '-y (-6),', '+z (-15),', '-z (16),']
# oops! child bond +x is not none, and we're not forcing
# oops! child bond -x is not none, and we're not forcing
# oops! child bond -y is not none, and we're not forcing
# oops! child bond +y is not none, and we're not forcing
# oops! child bond -z is not none, and we're not forcing
# oops! child bond +z is not none, and we're not forcing

# %%
painter.mesovoxel.structural_voxels
# Out:
# {0, 1, 2, 4, 5, 8}

# %%
voxel_3 = lattice.get_voxel(3)
cyan_bond = voxel_3.get_bond('-x')
print(cyan_bond.type)
# Out:
# structural

# %% [markdown]
# ## Visualize the painted lattice
#
# Run the below cell to view the painted lattice as a result from the algorithm.
#
# To view a specific binding flexibility in the app, just supply the given binding flexibility lattice as the argument to `RunVisualizer`.

# %%
# %gui qt

if __name__ == '__main__':
    if not QCoreApplication.instance():
        app = QApplication(sys.argv)
    else:
        app = QCoreApplication.instance()
    
    visualizeWindow = RunVisualizer(lattice=lattice, voxels=lattice.voxels.values(), app=app) # insert bf_lattice here if you want

# %% [markdown]
# ## Optional: Binding Flexibility
# In this section, we introduce an optional "binding flexibility" parameter, which modifies the final painting result to be stricter or looser. This is motivated by the observation that the geometry / symmetries of specific structures may perform better under different constraints, and we offer the user the option to make it more/less strict.
#
# ### Background
# **Binding flexibility 1:** Reduces specificity (less colors)
# - BF 1 turns all bonds to voxels in the same automorphism equivalence class are repainted to be the same color.
# - In other words, we repaint all bonds between all voxels with some symmetry between them to be the same color.
#
# **Binding flexibility 2:** No change
# - BF 2 is the default result from the Painter.paint() algorithm. It generally leads to the best results, so most systems are painted with this.
#
# **Binding flexibility 3:** Adds specificity (more colors)
# - Introducing a maximum cutoff ratio (= structural bonds / total bonds) per voxel.
# - For all voxels in the lattice with a cutoff ratio higher than the maximum, we repaint a NEW color ontop of a structural bond on that voxel to lower the ratio to satisfy the constraint.
# - This ratio is motivated by the observation that having more structural bonds on the same voxel makes it more likely to erroneously bind in ways we don't want.
#
# ### Usage
# To repaint the lattice with a specific binding flexibility, create a new `BindingFlexibility` instance specified with a given (painted) lattice object. Then run either `binding_flexibility1()` or `binding_flexibility3()` and assign it to a new variable to create a NEW lattice instance which can be visualized in the app. An example usage can be run below.

# %%
bf = BindingFlexibility(lattice)

bf1_lattice = bf.binding_flexibility_1()
bf3_lattice = bf.binding_flexibility_3(max_cutoff_ratio=1/6)
