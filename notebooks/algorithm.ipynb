# %% [markdown]
# # MOSES: DNA Coloring Algorithm
#
# Contributors: Dr. Jason Kahn (Brookhaven), Sarah Hong (Columbia)
#
# This notebook shows the final workflow for how to create a lattice structure and paint it.

# %%
# Load this cell so that changes made in other files will be automatically reflected
# %load_ext autoreload
# %autoreload 2

# %%
# Run this cell to load all imports
import sys
sys.path.append('../')

import numpy as np
from PyQt6.QtWidgets import QApplication
from PyQt6.QtCore import QCoreApplication

from app.design.Designer import RunDesigner
from app.visualize.Visualizer import RunVisualizer
from algorithm.lattice.Lattice2 import Lattice
from algorithm.painting.Painter2 import Painter
from algorithm.painting.BindingFlexibility import BindingFlexibility

# %% [markdown]
# ## Create the lattice
# Run the below cell to open a GUI which allows you to quickly create arbitrary lattice structures.
#
# These lattices are encoded as numpy arrays and are saved to a (renamable) file called `lattice.npy` in the `notebooks/data` subdirectory. You can also use this feature to save and reload arbitrary lattice designs you've previously created.

# %%
# %gui qt

if __name__ == '__main__':
    if not QCoreApplication.instance():
        app = QApplication(sys.argv)
    else:
        app = QCoreApplication.instance()
    
    designer = RunDesigner(app)
    input_lattice = designer.run()
    
    if input_lattice is not None:
        print('Lattice received.')
        # rename this to whatever you want to call your lattice
        np.save("data/lattice.npy", input_lattice) 
    else:
        print("No lattice received.")

# %% [markdown]
# ## Running the algorithm
#
# ### Load lattice from file
# We can load in the lattice we created with `np.load(filename.npy)`. Since the lattice is just a numpy array, you can also create your own arbitrary lattices without the designer by creating arbitrary numpy arrays yourself.
#
# Some examples to run:
# - `double_oreo.npy`
# - `perovskite.npy`
# - `mini_helix.npy`
# - `helix.npy`
#
# ### Painting algorithm
# All you need to do to run the algorithm is to create a Lattice instance, `compute_symmetries()`, create a Painter instance, and `paint_lattice()`.
#
# The example workflow is detailed below.

# %%
# input_lattice = np.load('data/double_oreo.npy', allow_pickle=True)

# An example lattice structure you can load in
input_lattice = np.load('data/perovskite.npy')

# Initialize the data structures and compute all symmetries
lattice = Lattice(input_lattice)
lattice.compute_symmetries()

# Paint the lattice
painter = Painter(lattice, verbose=True) # Set verbose=True to print debug
painter.paint_lattice()
# Out:
# ===== STARTING STR_PAINT_LATTICE =====
#
# --- PAINT S_BOND (1) ---
# voxel_0 ((1, 0, 0)) <---> voxel_1 ((-1, 0, 0))
# self-sym paint(voxel_0)
#     map_paint(parent_0 --> child_0, sym=translation, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=90° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=90° Y-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° Y-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° Y-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=90° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° X-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° X-axis + 270° Y-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° X-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° X-axis + 90° Y-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° X-axis + 90° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° Y-axis + 180° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° Y-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° Y-axis + 270° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° Y-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° Z-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=180° Z-axis + 90° Y-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° X-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° X-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° X-axis + 90° Y-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° Y-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° Y-axis + 270° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° Y-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° Y-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° Z-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=270° Z-axis + 90° Y-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=90° X-axis + 90° Y-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=90° Z-axis + 270° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=90° Z-axis + 270° Y-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=90° Z-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_0 --> child_0, sym=90° Z-axis + 90° Y-axis, with_negation=False)
# self-sym paint(voxel_1)
#     map_paint(parent_1 --> child_1, sym=translation, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=90° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=270° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Y-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Z-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° X-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Y-axis + 180° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Y-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Y-axis + 270° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Y-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Z-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=270° X-axis + 180° Z-axis, with_negation=False)
#
# --- PAINT S_BOND (2) ---
# voxel_1 ((0, 1, 0)) <---> voxel_3 ((0, -1, 0))
# self-sym paint(voxel_1)
#     map_paint(parent_1 --> child_1, sym=translation, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=90° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=270° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Y-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Z-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° X-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Y-axis + 180° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Y-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Y-axis + 270° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Y-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=180° Z-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_1 --> child_1, sym=270° X-axis + 180° Z-axis, with_negation=False)
# self-sym paint(voxel_3)
#     map_paint(parent_3 --> child_3, sym=translation, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° X-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Y-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=90° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=270° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° X-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° X-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° X-axis + 90° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Y-axis + 180° X-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Y-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#
# --- PAINT S_BOND (3) ---
# voxel_3 ((0, 0, 1)) <---> voxel_7 ((0, 0, -1))
# self-sym paint(voxel_3)
#     map_paint(parent_3 --> child_3, sym=translation, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° X-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Y-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=90° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=270° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° X-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° X-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° X-axis + 90° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Y-axis + 180° X-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Y-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_3 --> child_3, sym=180° Y-axis + 90° Z-axis, with_negation=False)
# self-sym paint(voxel_7)
#     map_paint(parent_7 --> child_7, sym=translation, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=90° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=90° Y-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° Y-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° Y-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=90° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° X-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° X-axis + 270° Y-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° X-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° X-axis + 90° Y-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° X-axis + 90° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° Y-axis + 180° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° Y-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° Y-axis + 270° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° Y-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° Y-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° Y-axis + 90° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° Z-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=180° Z-axis + 90° Y-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° X-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° X-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° X-axis + 90° Y-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° Y-axis + 180° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° Y-axis + 270° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° Y-axis + 270° Z-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° Y-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° Z-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=270° Z-axis + 90° Y-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=90° X-axis + 90° Y-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=90° Z-axis + 270° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=90° Z-axis + 270° Y-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=90° Z-axis + 90° X-axis, with_negation=False)
#     map_paint(parent_7 --> child_7, sym=90° Z-axis + 90° Y-axis, with_negation=False)
#
# ===== STARTING COMP_PAINT_LATTICE =====
#
# Mapping the mesovoxel onto the rest of the lattice...
# ---
# skipping 0, already in mesovoxel
# skipping 1, already in mesovoxel
# only str_mp 1 exists, mapping onto voxel 2
#     map_paint(parent_1 --> child_2, sym=90° Z-axis, with_negation=False)
# skipping 3, already in mesovoxel
# only str_mp 1 exists, mapping onto voxel 4
#     map_paint(parent_1 --> child_4, sym=90° Y-axis, with_negation=False)
# only str_mp 3 exists, mapping onto voxel 5
#     map_paint(parent_3 --> child_5, sym=90° X-axis, with_negation=False)
# only str_mp 3 exists, mapping onto voxel 6
#     map_paint(parent_3 --> child_6, sym=90° Y-axis, with_negation=False)
# skipping 7, already in mesovoxel

# %% [markdown]
# ## Visualize the painted lattice
#
# Run the below cell to view the painted lattice as a result from the algorithm.
#
# To view a specific binding flexibility in the app, just supply the given binding flexibility lattice as the argument to `RunVisualizer`.

# %%
# %gui qt

if __name__ == '__main__':
    if not QCoreApplication.instance():
        app = QApplication(sys.argv)
    else:
        app = QCoreApplication.instance()
    
    visualizeWindow = RunVisualizer(lattice=lattice, voxels=lattice.voxels.values(), app=app) # insert bf_lattice here if you want

# %% [markdown]
# ## Optional: Binding Flexibility
# In this section, we introduce an optional "binding flexibility" parameter, which modifies the final painting result to be stricter or looser. This is motivated by the observation that the geometry / symmetries of specific structures may perform better under different constraints, and we offer the user the option to make it more/less strict.
#
# ### Background
# **Binding flexibility 1:** Reduces specificity (less colors)
# - BF 1 turns all bonds to voxels in the same automorphism equivalence class are repainted to be the same color.
# - In other words, we repaint all bonds between all voxels with some symmetry between them to be the same color.
#
# **Binding flexibility 2:** No change
# - BF 2 is the default result from the Painter.paint() algorithm. It generally leads to the best results, so most systems are painted with this.
#
# **Binding flexibility 3:** Adds specificity (more colors)
# - Introducing a maximum cutoff ratio (= structural bonds / total bonds) per voxel.
# - For all voxels in the lattice with a cutoff ratio higher than the maximum, we repaint a NEW color ontop of a structural bond on that voxel to lower the ratio to satisfy the constraint.
# - This ratio is motivated by the observation that having more structural bonds on the same voxel makes it more likely to erroneously bind in ways we don't want.
#
# ### Usage
# To repaint the lattice with a specific binding flexibility, create a new `BindingFlexibility` instance specified with a given (painted) lattice object. Then run either `binding_flexibility1()` or `binding_flexibility3()` and assign it to a new variable to create a NEW lattice instance which can be visualized in the app. An example usage can be run below.

# %%
bf = BindingFlexibility(lattice)

bf1_lattice = bf.binding_flexibility_1()
bf3_lattice = bf.binding_flexibility_3(max_cutoff_ratio=1/6)
